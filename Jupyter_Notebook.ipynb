# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# My Jupyter Notebook on Visual Studio (IBM WATSON WOULD NOT WORK FOR ME!)

# %% [markdown]
# <b>James Hall</b>

# %% [markdown]
# Current Occupation: Product Manager

# %% [markdown]
# <i>I am interested in doing more Data Product Management

# %% [markdown]
# <h3> In cell 5 my code is supposed to count to 5 </h5>

# %%
print (1,2,3,4,5, sep = '\n')
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# **List of my things**<p>
# <p>>james hall blockquote
# <p>[Google](https://google.com)
# <p>We are laughing :joy:
# <p>~~None of this is working~~
#
# #Hello
# ##world
# ###Did you hear the news
# ####Not all markdown is supported by Github
